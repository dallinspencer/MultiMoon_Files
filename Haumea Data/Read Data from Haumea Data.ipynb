# %%
import pandas as pd
import numpy as np

df1_2010 = pd.read_csv('haumea_s1hst_2010.txt')
df1_2015 = pd.read_csv('haumea_s1hst_2015.txt')
df1_2016 = pd.read_csv('haumea_s1hst_2016.txt')
df2_2010 = pd.read_csv('haumea_s2hst_2010.txt')
df2_2015 = pd.read_csv('haumea_s2hst_2015.txt')
df2_2016 = pd.read_csv('haumea_s2hst_2016.txt')

print(df1_2010)
print(df1_2015)
print(df1_2016)
print(df2_2010)
print(df2_2015)
print(df2_2016)
# Out:
#            time        x        y       ex       ey
# 0   2453746.525 -0.20637  0.30013  0.00256  0.00256
# 1   2453746.554 -0.20832  0.30582  0.00257  0.00257
# 2   2454138.287 -0.21088  0.22019  0.00252  0.00197
# 3   2454138.304 -0.21132  0.22145  0.00095  0.00204
# 4   2454138.351 -0.21515  0.23185  0.00301  0.00206
# 5   2454138.368 -0.21402  0.23314  0.00192  0.00230
# 6   2454138.418 -0.21705  0.24202  0.00103  0.00282
# 7   2454138.435 -0.21449  0.24450  0.00323  0.00254
# 8   2454138.484 -0.21818  0.25301  0.00153  0.00224
# 9   2454138.501 -0.21807  0.25639  0.00310  0.00291
# 10  2454138.551 -0.22173  0.26308  0.00146  0.00230
# 11  2454138.567 -0.21978  0.26791  0.00202  0.00226
# 12  2454469.653  0.23786 -1.27383  0.00404  0.00824
# 13  2454593.726 -0.18297  1.08994  0.00354  0.00425
# 14  2454600.192  0.10847  0.17074  0.00508  0.00427
# 15  2454601.990  0.18374 -0.13041  0.00729  0.00504
# 16  2454603.788  0.24918 -0.43962  0.00207  0.00574
# ...
